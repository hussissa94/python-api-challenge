# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Keep an eye on your API usage. Use https://developers.google.com/maps/reporting/gmp-reporting as reference for how to monitor your usage and billing.
#
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
pip install gmaps
# Out:
# Collecting gmaps
#   Downloading gmaps-0.9.0.tar.gz (1.1 MB)
# Requirement already satisfied: ipython>=5.3.0 in d:\programdata\anaconda3\envs\truisttweet\lib\site-packages (from gmaps) (7.19.0)
# Requirement already satisfied: ipywidgets>=7.0.0 in d:\programdata\anaconda3\envs\truisttweet\lib\site-packages (from gmaps) (7.6.3)
# Requirement already satisfied: traitlets>=4.3.0 in d:\programdata\anaconda3\envs\truisttweet\lib\site-packages (from gmaps) (5.0.5)
# Requirement already satisfied: six in d:\programdata\anaconda3\envs\truisttweet\lib\site-packages (from gmaps) (1.15.0)
# Collecting geojson>=2.0.0
#   Downloading geojson-2.5.0-py2.py3-none-any.whl (14 kB)
# Requirement already satisfied: decorator in d:\programdata\anaconda3\envs\truisttweet\lib\site-packages (from ipython>=5.3.0->gmaps) (4.4.2)
# Requirement already satisfied: colorama in d:\programdata\anaconda3\envs\truisttweet\lib\site-packages (from ipython>=5.3.0->gmaps) (0.4.4)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in d:\programdata\anaconda3\envs\truisttweet\lib\site-packages (from ipython>=5.3.0->gmaps) (3.0.8)
# Requirement already satisfied: pickleshare in d:\programdata\anaconda3\envs\truisttweet\lib\site-packages (from ipython>=5.3.0->gmaps) (0.7.5)
# Requirement already satisfied: jedi>=0.10 in d:\programdata\anaconda3\envs\truisttweet\lib\site-packages (from ipython>=5.3.0->gmaps) (0.15.2)
# Requirement already satisfied: pygments in d:\programdata\anaconda3\envs\truisttweet\lib\site-packages (from ipython>=5.3.0->gmaps) (2.7.4)
# Requirement already satisfied: backcall in d:\programdata\anaconda3\envs\truisttweet\lib\site-packages (from ipython>=5.3.0->gmaps) (0.2.0)
# Requirement already satisfied: setuptools>=18.5 in d:\programdata\anaconda3\envs\truisttweet\lib\site-packages (from ipython>=5.3.0->gmaps) (51.1.2.post20210112)
# Requirement already satisfied: ipykernel>=4.5.1 in d:\programdata\anaconda3\envs\truisttweet\lib\site-packages (from ipywidgets>=7.0.0->gmaps) (5.3.4)
# Requirement already satisfied: nbformat>=4.2.0 in d:\programdata\anaconda3\envs\truisttweet\lib\site-packages (from ipywidgets>=7.0.0->gmaps) (5.1.2)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in d:\programdata\anaconda3\envs\truisttweet\lib\site-packages (from ipywidgets>=7.0.0->gmaps) (3.5.1)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in d:\programdata\anaconda3\envs\truisttweet\lib\site-packages (from ipywidgets>=7.0.0->gmaps) (1.0.0)
# Requirement already satisfied: tornado>=4.2 in d:\programdata\anaconda3\envs\truisttweet\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (6.1)
# Requirement already satisfied: jupyter-client in d:\programdata\anaconda3\envs\truisttweet\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (6.1.7)
# Requirement already satisfied: parso>=0.5.2 in d:\programdata\anaconda3\envs\truisttweet\lib\site-packages (from jedi>=0.10->ipython>=5.3.0->gmaps) (0.5.2)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in d:\programdata\anaconda3\envs\truisttweet\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (3.2.0)
# Requirement already satisfied: jupyter-core in d:\programdata\anaconda3\envs\truisttweet\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (4.7.0)
# Requirement already satisfied: ipython-genutils in d:\programdata\anaconda3\envs\truisttweet\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (0.2.0)
# Requirement already satisfied: attrs>=17.4.0 in d:\programdata\anaconda3\envs\truisttweet\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (20.3.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in d:\programdata\anaconda3\envs\truisttweet\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (0.17.3)
# Requirement already satisfied: wcwidth in d:\programdata\anaconda3\envs\truisttweet\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.3.0->gmaps) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in d:\programdata\anaconda3\envs\truisttweet\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (6.1.6)
# Requirement already satisfied: Send2Trash in d:\programdata\anaconda3\envs\truisttweet\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.5.0)
# Requirement already satisfied: argon2-cffi in d:\programdata\anaconda3\envs\truisttweet\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (20.1.0)
# Requirement already satisfied: terminado>=0.8.3 in d:\programdata\anaconda3\envs\truisttweet\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.9.2)
# Requirement already satisfied: jinja2 in d:\programdata\anaconda3\envs\truisttweet\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2.11.2)
# Requirement already satisfied: nbconvert in d:\programdata\anaconda3\envs\truisttweet\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (6.0.7)
# Requirement already satisfied: prometheus-client in d:\programdata\anaconda3\envs\truisttweet\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.9.0)
# Requirement already satisfied: pyzmq>=17 in d:\programdata\anaconda3\envs\truisttweet\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (20.0.0)
# Requirement already satisfied: python-dateutil>=2.1 in d:\programdata\anaconda3\envs\truisttweet\lib\site-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (2.8.1)
# Requirement already satisfied: pywin32>=1.0 in d:\programdata\anaconda3\envs\truisttweet\lib\site-packages (from jupyter-core->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (227)
# Requirement already satisfied: pywinpty>=0.5 in d:\programdata\anaconda3\envs\truisttweet\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.5.7)
# Requirement already satisfied: cffi>=1.0.0 in d:\programdata\anaconda3\envs\truisttweet\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.14.4)
# Requirement already satisfied: pycparser in d:\programdata\anaconda3\envs\truisttweet\lib\site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2.20)
# Requirement already satisfied: MarkupSafe>=0.23 in d:\programdata\anaconda3\envs\truisttweet\lib\site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.1.1)
# Requirement already satisfied: bleach in d:\programdata\anaconda3\envs\truisttweet\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (3.2.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in d:\programdata\anaconda3\envs\truisttweet\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.8.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in d:\programdata\anaconda3\envs\truisttweet\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.4.3)
# Requirement already satisfied: entrypoints>=0.2.2 in d:\programdata\anaconda3\envs\truisttweet\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.3)
# Requirement already satisfied: jupyterlab-pygments in d:\programdata\anaconda3\envs\truisttweet\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.1.2)
# Requirement already satisfied: defusedxml in d:\programdata\anaconda3\envs\truisttweet\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.6.0)
# Requirement already satisfied: testpath in d:\programdata\anaconda3\envs\truisttweet\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.4.4)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in d:\programdata\anaconda3\envs\truisttweet\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.5.1)
# Requirement already satisfied: async-generator in d:\programdata\anaconda3\envs\truisttweet\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.10)
# Requirement already satisfied: nest-asyncio in d:\programdata\anaconda3\envs\truisttweet\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.4.3)
# Requirement already satisfied: packaging in d:\programdata\anaconda3\envs\truisttweet\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (20.8)
# Requirement already satisfied: webencodings in d:\programdata\anaconda3\envs\truisttweet\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.5.1)
# Requirement already satisfied: pyparsing>=2.0.2 in d:\programdata\anaconda3\envs\truisttweet\lib\site-packages (from packaging->bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2.4.7)
# Building wheels for collected packages: gmaps
#   Building wheel for gmaps (setup.py): started
#   Building wheel for gmaps (setup.py): finished with status 'done'
#   Created wheel for gmaps: filename=gmaps-0.9.0-py2.py3-none-any.whl size=2076097 sha256=791685c24e56ca6d1a6982993c54e9c3a1008bbf3f7cea838791bb684f71bd54
#   Stored in directory: c:\users\sathya darapu\appdata\local\pip\cache\wheels\30\bd\87\d0d731ee712c34a4d6bace8b1dbf8c8932e22a1625b4a55be4
# Successfully built gmaps
# Installing collected packages: geojson, gmaps
# Successfully installed geojson-2.5.0 gmaps-0.9.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os

# Import API key
from configWeather import g_key

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
# Loan CSV file generated from WeatherPy Folder
weather_data_to_load = "../output_data/cities.csv"
weather_data = pd.read_csv(weather_data_to_load)
dropna_weather_data = weather_data.dropna()
dropna_weather_data.head(20)
# Out:
#     City_ID           City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         0         barrow  71.2906 -156.7887     35.62        75          40
# 1         1        rikitea -23.1203 -134.9692     74.26        75           0
# 2         2        fortuna  40.5982 -124.1573     62.42        69          90
# 3         3   punta arenas -53.1500  -70.9167     41.11       100           0
# 4         4   komsomolskiy  40.4272   71.7189     81.32        21           0
# 5         5           arua   3.0201   30.9111     81.12        47          21
# 6         6      cape town -33.9258   18.4232     71.11        59           0
# 7         7         albany  42.6001  -73.9662     71.80        73          88
# 8         8    pitkyaranta  61.5734   31.4792     64.35        66          37
# 9         9         faanui -16.4833 -151.7500     78.93        69           7
# 10       10         hobart -42.8794  147.3294     47.05        68          40
# 11       11     oum hadjer  13.2954   19.6966     91.18        47          58
# 12       12        mindelo  16.8901  -24.9804     85.55        62          40
# 13       13          vaini -21.2000 -175.2000     68.16        83          20
# 14       14  qasigiannguit  68.8193  -51.1922     48.45        94         100
# 15       15      saskylakh  71.9167  114.0833     55.35        59         100
# 16       16         avarua -21.2078 -159.7750     68.05        77          75
# 17       17    yellowknife  62.4560 -114.3525     54.12        76          75
# 18       18        salalah  17.0151   54.0924     80.69        83          75
# 19       19      katherine -14.4667  132.2667     73.72        28           0
#
#     Wind Speed Country        Date
# 0        23.02      US  1629123544
# 1        11.32      PF  1629123009
# 2         1.01      US  1629123136
# 3         9.22      CL  1629122996
# 4         6.91      UZ  1629123113
# 5         4.50      UG  1629123545
# 6        11.99      ZA  1629123526
# 7         2.30      US  1629123319
# 8        10.27      RU  1629123545
# 9        12.64      PF  1629123412
# 10        1.01      AU  1629123302
# 11        3.49      TD  1629123545
# 12       14.97      CV  1629123546
# 13        6.91      TO  1629123546
# 14        7.02      GL  1629123383
# 15        9.48      RU  1629123520
# 16        6.91      CK  1629123009
# 17       12.66      CA  1629123546
# 18       11.50      OM  1629123148
# 19        8.05      AU  1629123547

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
# Configure gmaps
gmaps.configure(api_key=g_key)
# Use the Lat and Lng as locations and Humidity as the weight.
locations = dropna_weather_data[["Lat", "Lng"]]

humidity = dropna_weather_data["Humidity"].astype(float)

# %%
# Add Heatmap layer to map.
fig = gmaps.figure()
print(len(locations))
# Create heat layer
heat_layer = gmaps.heatmap_layer(locations, weights=humidity)

# Add layer
fig.add_layer(heat_layer)

# Display figure
fig
# Out:
# 556
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
#applying filters to get the conditions as
# cloudiness == 0  - no clouds
# Max temp between 70 and 80
# Wind speed < 20
# hunidity < 80

# Filter vacation with zero cloudiness
vacation_no_cloud = dropna_weather_data[dropna_weather_data["Cloudiness"] == 0]

# Filter vacation with max temp above 70 degrees F
vacation_above_70_degrees = vacation_no_cloud[vacation_no_cloud["Max Temp"] > 70]

# Filter vacation with max temp below 80 degrees F
vacation_below_80_degrees = vacation_above_70_degrees[vacation_above_70_degrees["Max Temp"] < 80]
# Filter vacation with wind speed below 10 mph
vacation_slow_wind = vacation_below_80_degrees[vacation_below_80_degrees["Wind Speed"] < 20]
# Filter vacation with humidity below 60 %
perfect_vacation = vacation_slow_wind[vacation_slow_wind["Humidity"] < 80]
# Set Index
indexed_perfect_vacation = perfect_vacation.reset_index()
del indexed_perfect_vacation["index"]
indexed_perfect_vacation
# Out:
#     City_ID            City      Lat       Lng  Max Temp  Humidity  \
# 0         1         rikitea -23.1203 -134.9692     74.26        75
# 1         6       cape town -33.9258   18.4232     71.11        59
# 2        19       katherine -14.4667  132.2667     73.72        28
# 3        73     san vicente -26.6167  -54.1333     77.58        42
# 4        81        asuncion -25.3007  -57.6359     78.24        57
# 5       101       zonguldak  41.2500   31.8333     74.25        48
# 6       102     east london -33.0153   27.9116     70.74        60
# 7       185            vila  42.0304   -8.1588     75.70        30
# 8       194  port elizabeth -33.9180   25.5701     79.11        64
# 9       209        carballo  43.2130   -8.6910     74.75        77
# 10      297        mmabatho -25.8500   25.6333     73.36        33
# 11      311           kashi  39.4547   75.9797     79.81        22
# 12      332          baiyin  36.5583  104.2081     72.48        66
# 13      390         requena  39.4883   -1.1004     78.89        28
# 14      525       kununurra -15.7667  128.7333     78.78        17
#
#     Cloudiness  Wind Speed Country        Date
# 0            0       11.32      PF  1629123009
# 1            0       11.99      ZA  1629123526
# 2            0        8.05      AU  1629123547
# 3            0        4.00      AR  1629123556
# 4            0        5.75      PY  1629123458
# 5            0        8.95      TR  1629123562
# 6            0       13.80      ZA  1629123562
# 7            0        8.25      PT  1629123579
# 8            0       12.66      ZA  1629123421
# 9            0       10.83      ES  1629123584
# 10           0       11.50      ZA  1629123601
# 11           0        6.71      CN  1629123610
# 12           0       13.60      CN  1629123616
# 13           0       13.29      ES  1629123631
# 14           0        8.05      AU  1629123665

# %%
vaca_locations = indexed_perfect_vacation[["Lat", "Lng"]]

vaca_humidity = indexed_perfect_vacation["Humidity"].astype(float)

# Plot Heatmap
vaca_fig = gmaps.figure()

# Create heat layer
vaca_heat_layer = gmaps.heatmap_layer(vaca_locations, weights=vaca_humidity, 
                                 dissipating=False, max_intensity=50,
                                 point_radius=2.5)

# Add layer
vaca_fig.add_layer(vaca_heat_layer)

# Display figure
vaca_fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
# Hotel variable
hotel_df = indexed_perfect_vacation
hotel_ls = []

# Loop through narrowed down dataframe to get nearest hotel
for city in range(len(indexed_perfect_vacation["City"])):

    lat = indexed_perfect_vacation.loc[city]["Lat"]
    lng = indexed_perfect_vacation.loc[city]["Lng"]

    city_coords = f"{lat},{lng}"

    params = {
        "location": city_coords, 
        "types": "lodging",
        "radius": 5000,
        "key": g_key
    }

    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"   

    hotel_request = requests.get(base_url, params=params)
    hotel_response = hotel_request.json()

    try:
        hotel_ls.append(hotel_response["results"][0]["name"])
    except:
        hotel_ls.append("Nearest hotel not found")

# Dataframe with nearest hotel
hotel_df["Hotel Name"] = hotel_ls
hotel_df
# Out:
#     City_ID            City      Lat       Lng  Max Temp  Humidity  \
# 0         1         rikitea -23.1203 -134.9692     74.26        75
# 1         6       cape town -33.9258   18.4232     71.11        59
# 2        19       katherine -14.4667  132.2667     73.72        28
# 3        73     san vicente -26.6167  -54.1333     77.58        42
# 4        81        asuncion -25.3007  -57.6359     78.24        57
# 5       101       zonguldak  41.2500   31.8333     74.25        48
# 6       102     east london -33.0153   27.9116     70.74        60
# 7       185            vila  42.0304   -8.1588     75.70        30
# 8       194  port elizabeth -33.9180   25.5701     79.11        64
# 9       209        carballo  43.2130   -8.6910     74.75        77
# 10      297        mmabatho -25.8500   25.6333     73.36        33
# 11      311           kashi  39.4547   75.9797     79.81        22
# 12      332          baiyin  36.5583  104.2081     72.48        66
# 13      390         requena  39.4883   -1.1004     78.89        28
# 14      525       kununurra -15.7667  128.7333     78.78        17
#
#     Cloudiness  Wind Speed Country        Date  \
# 0            0       11.32      PF  1629123009
# 1            0       11.99      ZA  1629123526
# 2            0        8.05      AU  1629123547
# 3            0        4.00      AR  1629123556
# 4            0        5.75      PY  1629123458
# 5            0        8.95      TR  1629123562
# 6            0       13.80      ZA  1629123562
# 7            0        8.25      PT  1629123579
# 8            0       12.66      ZA  1629123421
# 9            0       10.83      ES  1629123584
# 10           0       11.50      ZA  1629123601
# 11           0        6.71      CN  1629123610
# 12           0       13.60      CN  1629123616
# 13           0       13.29      ES  1629123631
# 14           0        8.05      AU  1629123665
#
#                                         Nearest Hotel  \
# 0                                     People ThankYou
# 1                   Southern Sun Waterfront Cape Town
# 2                                     Pine Tree Motel
# 3                         Complejo Turístico Farelluk
# 4                 Crowne Plaza Asuncion, an IHG Hotel
# 5                                     Süleyman Tez Ev
# 6                                             Tu Casa
# 7                 Hotel Castrum Villae by Walk Hotels
# 8                              39 On Nile Guest House
# 9                                       Pazo do Souto
# 10                          Mahikeng Guest Apartments
# 11                                            帕米尔青年旅舍
# 12  GreenTree Alliance Gansu Baiyin Renmin Road Hotel
# 13                                      Hotel Avenida
# 14                                    Hotel Kununurra
#
#                                            Hotel Name
# 0                                     People ThankYou
# 1                   Southern Sun Waterfront Cape Town
# 2                                     Pine Tree Motel
# 3                         Complejo Turístico Farelluk
# 4                 Crowne Plaza Asuncion, an IHG Hotel
# 5                                     Süleyman Tez Ev
# 6                                             Tu Casa
# 7                 Hotel Castrum Villae by Walk Hotels
# 8                              39 On Nile Guest House
# 9                                       Pazo do Souto
# 10                          Mahikeng Guest Apartments
# 11                                            帕米尔青年旅舍
# 12  GreenTree Alliance Gansu Baiyin Renmin Road Hotel
# 13                                      Hotel Avenida
# 14                                    Hotel Kununurra

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Lat", "Lng"]]

# %%
# Add marker layer ontop of heat map
markers = gmaps.marker_layer(locations, info_box_content= [f"Nearest Hotel: {hotel}" for hotel in hotels])
vaca_fig.add_layer(markers)

# Display figure
vaca_fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
